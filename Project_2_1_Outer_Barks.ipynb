# %% [markdown]
# <a href="https://colab.research.google.com/github/kdkwall/Math-152/blob/main/Project_2_1_Outer_Barks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Project 2 Group: Outer Barks
# ##Topic 3: The Random Walk

# %% [markdown]
# Members: Jenna Borzellino, Kaden Wallace, Yingjie Liu, Sam Taylor

# %% [markdown]
# First, we will begin creating a random two dimensional walk by creating 2 lists for the changes in the x direction and changes in the y direction, and then making a loop that runs the random choice of directions for a walk and plot these two lists as a walk.

# %%
#1
import numpy as np
import matplotlib.pyplot as plt
def proj(n):
  #n is number of steps
  k=0
  a=0
  #to start our x,y coords
  #then make a list that will contain our x,y coords, and start with 0 already inside to signify starting at the origin
  K=[0]
  A=[0]
  D=[] #this is for storing our choices
  for i in range(n):
    choice=np.random.choice(['U','D','L','R']) #this gives a random choice between up down left or right
    if choice=='U':
      a+=1 #when the random choice is 'U' we add one to our Y axis to simulate the person taking a step forward
    elif choice=='D':
      a-=1 #when the random choice is 'D' we subtract one from our Y axis to simulate the person taking a step backward
    elif choice=='L':
      k-=1 #when the random choice is 'L' we subtract one from our X axis to simulate the person is taking a step left
    elif choice=='R':
      k+=1 #when the random choice is 'R' we add one to our X axis to simulate the person is taking a step right
    K.append(k)
    A.append(a) 
    D.append(choice) #after each loop we then add the changes to our lists of x and y values as well as a list containing the direction of each step
  #print(K)
  #print(A)
  #print(D) #these print statements are to make sure everything is working correctly
  plt.xlabel('Steps in X direction')
  plt.ylabel('Steps in Y direction') #our x,y labels
  plt.plot(K,A,c='blue',label='walking path') #plotting our walking path
  plt.scatter(0,0,alpha=1,c='orange',label='start',marker='x') 
  plt.scatter(K[-1],A[-1],alpha=1,c='red',label='end',marker='x') #plotting points at the start and end of the walk
  plt.legend() #our legend
  plt.grid() #grid lines
  plt.show() #to show

proj(1000) #calling our function with 1000 steps

# %% [markdown]
# Next, using the same function as before, I wanted to have a change in the x,y directions to create a diagoal step instead of up or down step. I wanted to have a change in the x,y directions at the same time to see what would happen and expect this to produce the diagonal steps.

# %%
#I can use the same funtion as before with just a few changes
import numpy as np
import matplotlib.pyplot as plt
def proj_2(n):
  #n is number of steps
  k=0
  a=0
  #to start our x,y coords
  #then make a list that will contain our x,y coords, and start with 0 already inside to signify starting at the origin
  K=[0]
  A=[0]
  D=[] #this is for storing our choices
  for i in range(n):
    choice_x=np.random.choice(['L','R','Nothing']) #this gives a random choice between left or right
    choice_y=np.random.choice(['U','D','Nothing']) #this gives a random choice between up down 
    if choice_y=='U':
      a+=1 #when the random choice is 'U' we add one to our Y axis to simulate the person taking a step forward
      if choice_x=='L':
        k-=1 #when the random choice is 'L' we subtract one from our X axis to simulate the person is taking a step left
      elif choice_x=='R':
        k+=1 #when the random choice is 'R' we add one to our X axis to simulate the person is taking a step right
    elif choice_y=='D':
      a-=1 #when the random choice is 'D' we subtract one from our Y axis to simulate the person taking a step backward
      if choice_x=='L':
        k-=1 #when the random choice is 'L' we subtract one from our X axis to simulate the person is taking a step left
      elif choice_x=='R':
        k+=1 #when the random choice is 'R' we add one to our X axis to simulate the person is taking a step right
    K.append(k)
    A.append(a) 
    D.append(choice_x) #after each loop we then add the changes to our lists of x and y values as well as a list containing the direction of each step
    D.append(choice_y)
  #print(K)
  #print(A)
  #print(D) #these print statements are to make sure everything is working correctly
  plt.figure(figsize=(10,10)) #making it bigger
  plt.xlabel('Steps in X direction')
  plt.ylabel('Steps in Y direction') #our x,y labels
  plt.plot(K,A,c='blue',label='walking path') #plotting our walking path
  plt.scatter(0,0,alpha=1,c='purple',label='start',marker='o') #changed to purple so you can see better
  plt.scatter(K[-1],A[-1],alpha=1,c='red',label='end',marker='x') #plotting points at the start and end of the walk
  plt.legend() #our legend
  plt.grid() #grid lines
  plt.show() #to show

proj_2(1000) #calling our function with 1000 steps

# %% [markdown]
# Now lets change this to a PIL image:

# %%
import numpy as np
from PIL import Image, ImageDraw

def proj_2PIL(n,size):
  #n is number of steps
  k=0
  a=0
  #to start our x,y coords
  #then make a list that will contain our x,y coords, and start with 0 already inside to signify starting at the origin
  K=[0]
  A=[0]
  D=[] #this is for storing our choices
  for i in range(n):
    choice_x=np.random.choice(['L','R','Nothing']) #this gives a random choice between left or right
    choice_y=np.random.choice(['U','D','Nothing']) #this gives a random choice between up down 
    if choice_y=='U':
      a+=1 #when the random choice is 'U' we add one to our Y axis to simulate the person taking a step forward
      if choice_x=='L':
        k-=1 #when the random choice is 'L' we subtract one from our X axis to simulate the person is taking a step left
      elif choice_x=='R':
        k+=1 #when the random choice is 'R' we add one to our X axis to simulate the person is taking a step right
    elif choice_y=='D':
      a-=1 #when the random choice is 'D' we subtract one from our Y axis to simulate the person taking a step backward
      if choice_x=='L':
        k-=1 #when the random choice is 'L' we subtract one from our X axis to simulate the person is taking a step left
      elif choice_x=='R':
        k+=1 #when the random choice is 'R' we add one to our X axis to simulate the person is taking a step right
    K.append(k)
    A.append(a) 
    D.append(choice_x) #after each loop we then add the changes to our lists of x and y values as well as a list containing the direction of each step
    D.append(choice_y)
    # Determine the width and height of the image
    width = (max(K) - min(K) + 1) * size
    height = (max(A) - min(A) + 1) * size
    origin_x = abs(min(K)) 
    origin_y = abs(min(A))
  img = Image.new("RGB", (width, height), "white")#then we create an image
  draw = ImageDraw.Draw(img)
  # Draw the points on the image
  for i in range(n+1):
      x = (K[i] + origin_x) * size
      y = (A[i] + origin_y) * size
      draw.rectangle([x, y, x+size, y+size], fill=np.random.choice(['magenta','green',"yellow"])) #this draws with a random chance of being 'magenta','green',"yellow"
  img.show()  # this the image

proj_2PIL(1000, 5)  # this calls our function with 1000 steps and an image size of 5
# Out:
# <PIL.Image.Image image mode=RGB size=140x185 at 0x7FBDEE7E5580>

# %% [markdown]
# Now, for probelm 2, lets make some walls. I'll start by making the making walls at the lines x=0 and y=0, so if the walker hits the walls it can either go in the opposite direction, or along the wall.

# %%
#2
#I can use the same funtion as before with just a few changes
import numpy as np
import matplotlib.pyplot as plt
def proj_3(n):
  #n is number of steps
  k=0
  a=0
  #to start our x,y coords
  #then make a list that will contain our x,y coords, and start with 0 already inside to signify starting at the origin
  K=[0]
  A=[0]
  D=[] #this is for storing our choices
  for i in range(n):
    choice_x=np.random.choice(['L','R']) #this gives a random choice between left or right
    choice_y=np.random.choice(['U','D']) #this gives a random choice between up down 
    if choice_y=='U':
      a+=1 #when the random choice is 'U' we add one to our Y axis to simulate the person taking a step forward
      if choice_x=='L':
        if k==0: #here we check to see if we are at a wall
          k+=0
        else:
          k-=1 #when the random choice is 'L' we subtract one from our X axis to simulate the person is taking a step left
      elif choice_x=='R':
        k+=1 #when the random choice is 'R' we add one to our X axis to simulate the person is taking a step right
    elif choice_y=='D':
      if a==0: #here we check to see if we are at a wall
        a+=0
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 #when the random choice is 'L' we subtract one from our X axis to simulate the person is taking a step left
        elif choice_x=='R':
          k+=1 #when the random choice is 'R' we add one to our X axis to simulate the person is taking a step right
      else:
        a-=1 #when the random choice is 'D' we subtract one from our Y axis to simulate the person taking a step backward
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 #when the random choice is 'L' we subtract one from our X axis to simulate the person is taking a step left
        elif choice_x=='R':
          k+=1 #when the random choice is 'R' we add one to our X axis to simulate the person is taking a step right
    K.append(k)
    A.append(a) 
    D.append(choice_x) #after each loop we then add the changes to our lists of x and y values as well as a list containing the direction of each step
    D.append(choice_y)
  #print(K)
  #print(A)
  #print(D) #these print statements are to make sure everything is working correctly
  plt.figure(figsize=(10,10)) #making it bigger
  plt.xlabel('Steps in X direction')
  plt.ylabel('Steps in Y direction') #our x,y labels
  plt.plot(K,A,c='blue',label='walking path') #plotting our walking path
  plt.scatter(0,0,alpha=1,c='purple',label='start',marker='o') #changed to purple so you can see better
  plt.scatter(K[-1],A[-1],alpha=1,c='red',label='end',marker='x') #plotting points at the start and end of the walk
  plt.legend() #our legend
  plt.grid() #grid lines
  plt.show() #to show

proj_3(1000) #calling our function with 1000 steps

# %% [markdown]
# Since that worked, lets create a 20x20 box surrounding the grid and use this box perimeter as walls. We will also add a PIL version of the graph to compare.

# %%
#I can use the same funtion as before with just a few changes
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image,ImageDraw
def proj_4(n,size):
  #n is number of steps
  k=0
  a=0
  #to start our x,y coords
  #then make a list that will contain our x,y coords, and start with 0 already inside to signify starting at the origin
  K=[0]
  A=[0]
  D=[] #this is for storing our choices
  for i in range(n):
    choice_x=np.random.choice(['L','R']) #this gives a random choice between left or right
    choice_y=np.random.choice(['U','D']) #this gives a random choice between up down 
    if choice_y=='U':
      if a==20:
        a+=0
      else:
        a+=1 
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
              k+=0
          else:
              k+=1
    elif choice_y=='D':
      if a==0: #here we check to see if we are at a wall
        a+=0
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
            k+=0
          else:
            k+=1
      else:
        a-=1 
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 
        elif choice_x=='R':          
          if k==20: #here we check to see if we are at a wall
            k+=0
          else:
            k+=1
    K.append(k)
    A.append(a) 
    D.append(choice_x) #after each loop we then add the changes to our lists of x and y values as well as a list containing the direction of each step
    D.append(choice_y)
  #print(K)
  #print(A)
  #print(D) #these print statements are to make sure everything is working correctly
  plt.figure(figsize=(10,10)) #making it bigger
  plt.xlabel('Steps in X direction')
  plt.ylabel('Steps in Y direction') #our x,y labels
  plt.plot(K,A,c='blue',label='walking path') #plotting our walking path
  plt.scatter(0,0,alpha=1,c='purple',label='start',marker='o') #changed to purple so you can see better
  plt.scatter(K[-1],A[-1],alpha=1,c='red',label='end',marker='x') #plotting points at the start and end of the walk
  plt.legend() #our legend
  plt.grid() #grid lines
  plt.show() #to show
   # Determine the width and height of the image
  width = (max(K) - min(K) + 1) * size
  height = (max(A) - min(A) + 1) * size
  origin_x = abs(min(K)) 
  origin_y = abs(min(A))
  img = Image.new("RGB", (width, height), "white")#then we create an image
  draw = ImageDraw.Draw(img)
  # Draw the points on the image
  for i in range(n+1):
      x = (K[i] + origin_x) * size
      y = (A[i] + origin_y) * size
      draw.rectangle([x, y, x+size, y+size], fill=np.random.choice(['magenta','green',"yellow"])) #this draws with a random chance of being 'magenta','green',"yellow"
  img.show()  # this the image

proj_4(1000, 20)  # this calls our function with 1000 steps and an image size of 20
# Out:
# <PIL.Image.Image image mode=RGB size=420x420 at 0x7F8AF74AEFA0>

# %% [markdown]
# Our PIL image looks like it places pixels in the right places, however the y axis looks as though y=0 is at the top rather than the bottem.
#
# Next, for our gravity walk, we are going to simulate an ant walking on up a wall, so the steps going up would be harder than the steps going down. If we adjust the y element down a small amount every time the loop runs it should simulate this. The way this was implemented into our walking graph was we made the steps up be slightly smaller, whereas the steps going down will be slightly larger.

# %%
#3
#I can use the same funtion as before with just a few changes
import numpy as np
import matplotlib.pyplot as plt
def proj_5(n):
  #n is number of steps
  k=0
  a=0
  #to start our x,y coords
  #then make a list that will contain our x,y coords, and start with 0 already inside to signify starting at the origin
  K=[0]
  A=[0]
  D=[] #this is for storing our choices
  for i in range(n):
    a-=.1
    choice_x=np.random.choice(['L','R']) #this gives a random choice between left or right
    choice_y=np.random.choice(['U','D']) #this gives a random choice between up down 
    if choice_y=='U':
      if a==20:
        a+=0
      else:
        a+=1 
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
              k+=0
          else:
              k+=1
    elif choice_y=='D':
      if a<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
        a+=abs(a)
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
            k+=0
          else:
            k+=1
      else:
        a-=1 
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 
        elif choice_x=='R':          
          if k==20: #here we check to see if we are at a wall
            k+=0
          else:
            k+=1
    K.append(k)
    A.append(a) 
    D.append(choice_x) #after each loop we then add the changes to our lists of x and y values as well as a list containing the direction of each step
    D.append(choice_y)
  #print(K)
  #print(A)
  #print(D) #these print statements are to make sure everything is working correctly
  plt.figure(figsize=(10,10)) #making it bigger
  plt.xlabel('Steps in X direction')
  plt.ylabel('Steps in Y direction') #our x,y labels
  plt.plot(K,A,c='blue',label='walking path') #plotting our walking path
  plt.scatter(0,0,alpha=1,c='purple',label='start',marker='o') #changed to purple so you can see better
  plt.scatter(K[-1],A[-1],alpha=1,c='red',label='end',marker='x') #plotting points at the start and end of the walk
  plt.legend() #our legend
  plt.grid() #grid lines
  plt.show() #to show

proj_5(1000) #calling our function with 1000 steps

# %% [markdown]
# As shown above, the graph looks crazy, and it dips below zero, which can't work (in our world, the ant can't go underground). So, to fix this problem we will try putting the if statement in a different place and try some different numbers for gravity.

# %%
#I can use the same funtion as before with just a few changes
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image,ImageDraw
def proj_6(n,size):
  #n is number of steps
  k=0
  a=0
  #to start our x,y coords
  #then make a list that will contain our x,y coords, and start with 0 already inside to signify starting at the origin
  K=[0]
  A=[0]
  D=[] #this is for storing our choices
  for i in range(n):
    choice_x=np.random.choice(['L','R']) #this gives a random choice between left or right
    choice_y=np.random.choice(['U','D']) #this gives a random choice between up down 
    if choice_y=='U':
      if a<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
        a+=abs(a)+1
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
            k+=0
          else:
            k+=1
      elif a==20:
        a+=0
      else:
        a+=1 
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
              k+=0
          else:
              k+=1
    elif choice_y=='D':
      if a<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
        a+=abs(a)
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
            k+=0
          else:
            k+=1
      else:
        a-=1
        if a<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
          a+=abs(a)
          if choice_x=='L':
            if k==0: #here we check to see if we are at a wall
              k+=0
            else:
              k-=1 
          elif choice_x=='R':          
            if k==20: #here we check to see if we are at a wall
              k+=0
            else:
              k+=1
        else:
          if choice_x=='L':
            if k==0: #here we check to see if we are at a wall
              k+=0
            else:
              k-=1 
          elif choice_x=='R':          
            if k==20: #here we check to see if we are at a wall
              k+=0
            else:
              k+=1
    K.append(k)
    A.append(a) 
    D.append(choice_x) #after each loop we then add the changes to our lists of x and y values as well as a list containing the direction of each step
    D.append(choice_y)
    a-=.1*a #our gravity, basing it on how high we are
  #print(K)
  #print(A)
  #print(D) #these print statements are to make sure everything is working correctly
  plt.figure(figsize=(10,10)) #making it bigger
  plt.xlabel('Steps in X direction')
  plt.ylabel('Steps in Y direction') #our x,y labels
  plt.plot(K,A,c='blue',label='walking path') #plotting our walking path
  plt.scatter(0,0,alpha=1,c='purple',label='start',marker='o') #changed to purple so you can see better
  plt.scatter(K[-1],A[-1],alpha=1,c='red',label='end',marker='x') #plotting points at the start and end of the walk
  plt.legend() #our legend
  plt.grid() #grid lines
  plt.show() #to show
  width = int((max(K) - min(K) + 1) * size)#we have to change these because the image doesnt accept floats for size
  height = int((max(A) - min(A) + 1) * size)
  origin_x = 0 
  origin_y = 0
  img = Image.new("RGB", (width, height), "white")#then we create an image
  draw = ImageDraw.Draw(img)
  # Draw the points on the image
  for i in range(n+1):
      x = (K[i] + origin_x) * size
      y = (A[i] + origin_y) * size
      draw.rectangle([x, y, x+size, y+size], fill=np.random.choice(['red','blue',"black"])) #this draws with a random chance of being 'red','blue',"black"
  img.show()  # this the image

proj_6(1000,25)  # this calls our function with 1000 steps and an image size of 25
# Out:
# <PIL.Image.Image image mode=RGB size=525x186 at 0x7F8ACFA2F490>

# %% [markdown]
# This graph above looks much better, and the steps can be seen as much more steep, which helped show the gravity more clearly. Also, the PIL seems to have a different ranges of Y values than the graph. It's still representing the Y axis at the top of the image however now its range looks shortened from the original.

# %% [markdown]
# Now that we have a graph of this ant going up a wall with some gravity on it, we would like to see what would happen if the ant was just moving up and to the right on the wall.

# %%
#I can use the same funtion as before with just a few changes
import numpy as np
import matplotlib.pyplot as plt
def proj_7(n,size):
  #n is number of steps
  k=0
  a=0
  #to start our x,y coords
  #then make a list that will contain our x,y coords, and start with 0 already inside to signify starting at the origin
  K=[0]
  A=[0]
  D=[] #this is for storing our choices
  for i in range(n):
    choice_x=np.random.choice(['R','Dont Move']) #this gives a random choice between left or right
    choice_y=np.random.choice(['U','Dont Move']) #this gives a random choice between up down 
    if choice_y=='U':
      if a<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
        a+=abs(a)+1
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
            k+=0
          else:
            k+=1
      elif a==20:
        a+=0
      else:
        a+=1 
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
              k+=0
          else:
              k+=1
    elif choice_y=='D':
      if a<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
        a+=abs(a)
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=0
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
            k+=0
          else:
            k+=1
      else:
        a-=1
        if a<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
          a+=abs(a)
          if choice_x=='L':
            if k==0: #here we check to see if we are at a wall
              k+=0
            else:
              k-=1 
          elif choice_x=='R':          
            if k==20: #here we check to see if we are at a wall
              k+=0
            else:
              k+=1
        else:
          if choice_x=='L':
            if k==0: #here we check to see if we are at a wall
              k+=0
            else:
              k-=1 
          elif choice_x=='R':          
            if k==20: #here we check to see if we are at a wall
              k+=0
            else:
              k+=1
    K.append(k)
    A.append(a) 
    D.append(choice_x) #after each loop we then add the changes to our lists of x and y values as well as a list containing the direction of each step
    D.append(choice_y)
    a-=.5*a
  #print(K)
  #print(A)
  #print(D) #these print statements are to make sure everything is working correctly
  plt.figure(figsize=(10,10)) #making it bigger
  plt.xlabel('Steps in X direction')
  plt.ylabel('Steps in Y direction') #our x,y labels
  plt.plot(K,A,c='blue',label='walking path') #plotting our walking path
  plt.scatter(0,0,alpha=1,c='purple',label='start',marker='o') #changed to purple so you can see better
  plt.scatter(K[-1],A[-1],alpha=1,c='red',label='end',marker='x') #plotting points at the start and end of the walk
  plt.legend() #our legend
  plt.grid() #grid lines
  plt.show() #to show
  width = int((max(K) - min(K) + 1) * size)#we have to change these because the image doesnt accept floats for size
  height = int((max(A) - min(A) + 1) * size)
  origin_x = 0 
  origin_y = 0
  img = Image.new("RGB", (width, height), "white")#then we create an image
  draw = ImageDraw.Draw(img)
  # Draw the points on the image
  for i in range(n+1):
      x = (K[i] + origin_x) * size
      y = (A[i] + origin_y) * size
      draw.rectangle([x, y, x+size, y+size], fill=np.random.choice(['green','yellow',"black"])) #this draws with a random chance of being green,yellow,black
  img.show()  # this the image

proj_7(1000,25)  # this calls our function with 1000 steps and an image size of 25
# Out:
# <PIL.Image.Image image mode=RGB size=525x74 at 0x7F8ACF93BDC0>

# %% [markdown]
# As you can see, this looks more like a function rather than a walking path, which makes sense since the ant can only move up or to the right. However, as shown, we can see that the because sometimes the ant does not move right or up, but because of the gravity it will fall down a little bit.
#
# This also produces a skinnier image for PIL, and almost resembles a snake so I decided to try and make the colors accordingly.

# %% [markdown]
# Now lets try out the bouncy box. Here, we will show what happens if the walking ant bounces off of the wall.

# %%
#4
#I can use the same funtion as before with just a few changes
import numpy as np
import matplotlib.pyplot as plt
def proj_8(n,size):
  #n is number of steps
  k=0
  a=0
  #to start our x,y coords
  #then make a list that will contain our x,y coords, and start with 0 already inside to signify starting at the origin
  K=[0]
  A=[0]
  D=[] #this is for storing our choices
  for i in range(n):
    choice_x=np.random.choice(['L','R','Nothing']) #this gives a random choice between left or right
    choice_y=np.random.choice(['U','D','Nothing']) #this gives a random choice between up down 
    if choice_y=='U':
      if a<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
        a+=abs(a)+1
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=1 #making left wall at x=0 bouncy
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
            k-=1 #making right wall at x=20 bouncy
          else:
            k+=1
      elif a==20:
        a-=1 #adding bouncy cieling
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=1 #making left wall at x=0 bouncy
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
               k-=1 #making right wall at x=20 bouncy
          else:
              k+=1
      else:
        a+=1 
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=1 #making left wall at x=0 bouncy
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
               k-=1 #making right wall at x=20 bouncy
          else:
              k+=1
    elif choice_y=='D':
      if a<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
        a+=abs(a)
        if choice_x=='L':
          if k==0: #here we check to see if we are at a wall
            k+=1
          else:
            k-=1 
        elif choice_x=='R':
          if k==20: #here we check to see if we are at a wall
            k-=1 #making right wall at x=20 bouncy
          else:
            k+=1
      else:
        a-=1
        if a<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
          a+=abs(a)
          if choice_x=='L':
            if k==0: #here we check to see if we are at a wall
              k+=1
            else:
              k-=1 
          elif choice_x=='R':          
            if k==20: #here we check to see if we are at a wall
              k-=1 #making right wall at x=20 bouncy
            else:
              k+=1
        else:
          if choice_x=='L':
            if k==0: #here we check to see if we are at a wall
              k+=1
            else:
              k-=1 
          elif choice_x=='R':          
            if k==20: #here we check to see if we are at a wall
              k-=1
            else:
              k+=1
    K.append(k)
    A.append(a) 
    D.append(choice_x) #after each loop we then add the changes to our lists of x and y values as well as a list containing the direction of each step
    D.append(choice_y)
    a-=.1*a #our gravity, basing it on how high we are
  #print(K)
  #print(A)
  #print(D) #these print statements are to make sure everything is working correctly
  plt.figure(figsize=(10,10)) #making it bigger
  plt.xlabel('Steps in X direction')
  plt.ylabel('Steps in Y direction') #our x,y labels
  plt.plot(K,A,c='blue',label='walking path') #plotting our walking path
  plt.scatter(0,0,alpha=1,c='purple',label='start',marker='o') #changed to purple so you can see better
  plt.scatter(K[-1],A[-1],alpha=1,c='red',label='end',marker='x') #plotting points at the start and end of the walk
  plt.legend() #our legend
  plt.grid() #grid lines
  plt.show() #to show
  width = int((max(K) - min(K) + 1) * size)#we have to change these because the image doesnt accept floats for size
  height = int((max(A) - min(A) + 1) * size)
  origin_x = 0 
  origin_y = 0
  img = Image.new("RGB", (width, height), "white")#then we create an image
  draw = ImageDraw.Draw(img)
  # Draw the points on the image
  for i in range(n+1):
      x = (K[i] + origin_x) * size
      y = (A[i] + origin_y) * size
      draw.rectangle([x, y, x+size, y+size], fill=np.random.choice(['blue','white',"yellow"])) #this draws with a random chance of being 'blue','white',"yellow"
  img.show()  # this the image

proj_8(1000,25)  # this calls our function with 1000 steps and an image size of 25
# Out:
# <PIL.Image.Image image mode=RGB size=525x175 at 0x7F8ACF1BD040>

# %% [markdown]
# This graph is obviously much more hectic than our other ones due to the bouncing off of the walls, there is a lot more movement than in the other graphs. This leads to the PIL image looking a bit more hectic that our previos box. It resembled rain falling so I tried to make it look like that with the colors.

# %% [markdown]
# Now for number 5, Id like to do this one with the code I used previously so im going to create a function that runs our old walk twice and combines the two graphs we produce.
# First lets create our function, then run it with two different variables. After that we will set one function to begin at 20,20 and the other at 0,0 and see how many collisions occured between the walkers and the end points of each.

# %%
#5
#I can use the same funtion as before with just a few changes
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image,ImageDraw
def proj_8(n,size):
  #n is number of steps
  k1=0
  k2=20
  a1=0
  a2=20
  #to start our x,y coords
  #then make a list that will contain our x,y coords, and start with 0 already inside to signify starting at the origin
  K1=[0]
  K2=[20]
  A1=[0]
  A2=[20]
  D1=[]
  D2=[]
  Collide_x=[]
  Collide_y=[]
  #now first, we should check if we are colliding

  for i in range(n):
    choice_x1=np.random.choice(['L','R','Nothing']) #this gives a random choice between left or right or nothing
    choice_y1=np.random.choice(['U','D','Nothing']) #this gives a random choice between up down or nothing
    choice_x2=np.random.choice(['L','R','Nothing']) #this gives a random choice between left or right or nothing
    choice_y2=np.random.choice(['U','D','Nothing']) #this gives a random choice between up down or nothing
    if k1==k2 and a1==a2:
      Collide_y.append(a2)
      Collide_x.append(k2)
      if choice_x2=='L':
        choice_x2=='R'
      elif choice_x2=='R':
        choice_x2=='L'
      if choice_y2=='U':
        choice_y2=='D'
      elif choice_y2=='D':
        choice_y2=='U'
      if choice_x1=='L':
        choice_x1=='R'
      elif choice_x1=='R':
        choice_x1=='L'
      if choice_y1=='U':
        choice_y1=='D'
      elif choice_y1=='D':
        choice_y1=='U'
      #by checking it like this we are able to reverse the direction they were heading and simulate a "bounce off"
    if choice_y1=='U':
      if a1<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
        a1+=abs(a1)+1
        if choice_x1=='L':
          if k1==0: #here we check to see if we are at a wall
            k1+=1 #making left wall at x=0 bouncy
          else:
            k1-=1 
        elif choice_x1=='R':
          if k1==20: #here we check to see if we are at a wall
            k1-=1 #making right wall at x=20 bouncy
          else:
            k1+=1
      elif a1==20:
        a1-=1 #adding bouncy cieling
        if choice_x1=='L':
          if k1==0: #here we check to see if we are at a wall
            k1+=1 #making left wall at x=0 bouncy
          else:
            k1-=1 
        elif choice_x1=='R':
          if k1==20: #here we check to see if we are at a wall
               k1-=1 #making right wall at x=20 bouncy
          else:
              k1+=1
      else:
        a1+=1 
        if choice_x1=='L':
          if k1==0: #here we check to see if we are at a wall
            k1+=1 #making left wall at x=0 bouncy
          else:
            k1-=1 
        elif choice_x1=='R':
          if k1==20: #here we check to see if we are at a wall
               k1-=1 #making right wall at x=20 bouncy
          else:
              k1+=1
    elif choice_y1=='D':
      if a1<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
        a1+=abs(a1)
        if choice_x1=='L':
          if k1==0: #here we check to see if we are at a wall
            k1+=1
          else:
            k1-=1 
        elif choice_x1=='R':
          if k1==20: #here we check to see if we are at a wall
            k1-=1 #making right wall at x=20 bouncy
          else:
            k1+=1
      else:
        a1-=1
        if a1<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
          a1+=abs(a1)
          if choice_x1=='L':
            if k1==0: #here we check to see if we are at a wall
              k1+=1
            else:
              k1-=1 
          elif choice_x1=='R':          
            if k1==20: #here we check to see if we are at a wall
              k1-=1 #making right wall at x=20 bouncy
            else:
              k1+=1
        else:
          if choice_x1=='L':
            if k1==0: #here we check to see if we are at a wall
              k1+=1
            else:
              k1-=1 
          elif choice_x1=='R':          
            if k1==20: #here we check to see if we are at a wall
              k1-=1
            else:
              k1+=1
    if choice_y2=='U':
      if a2<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
        a2+=abs(a2)+1
        if choice_x2=='L':
          if k2==0: #here we check to see if we are at a wall
            k2+=1 #making left wall at x=0 bouncy
          else:
            k2-=1 
        elif choice_x2=='R':
          if k2==20: #here we check to see if we are at a wall
            k2-=1 #making right wall at x=20 bouncy
          else:
            k2+=1
      elif a2==20:
        a2-=1 #adding bouncy cieling
        if choice_x2=='L':
          if k2==0: #here we check to see if we are at a wall
            k2+=1 #making left wall at x=0 bouncy
          else:
            k2-=1 
        elif choice_x2=='R':
          if k2==20: #here we check to see if we are at a wall
               k2-=1 #making right wall at x=20 bouncy
          else:
              k2+=1
      else:
        a2+=1 
        if choice_x2=='L':
          if k2==0: #here we check to see if we are at a wall
            k2+=1 #making left wall at x=0 bouncy
          else:
            k2-=1 
        elif choice_x2=='R':
          if k2==20: #here we check to see if we are at a wall
               k2-=1 #making right wall at x=20 bouncy
          else:
              k2+=1
    elif choice_y2=='D':
      if a2<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
        a2+=abs(a2)
        if choice_x2=='L':
          if k2==0: #here we check to see if we are at a wall
            k2+=1
          else:
            k2-=1 
        elif choice_x2=='R':
          if k2==20: #here we check to see if we are at a wall
            k2-=1 #making right wall at x=20 bouncy
          else:
            k2+=1
      else:
        a2-=1
        if a2<=0: #here we check to see if we are at or below the floor and bounce up however much weve gone below
          a2+=abs(a2)
          if choice_x2=='L':
            if k2==0: #here we check to see if we are at a wall
              k2+=1
            else:
              k2-=1 
          elif choice_x2=='R':          
            if k2==20: #here we check to see if we are at a wall
              k2-=1 #making right wall at x=20 bouncy
            else:
              k2+=1
        else:
          if choice_x2=='L':
            if k2==0: #here we check to see if we are at a wall
              k2+=1
            else:
              k2-=1 
          elif choice_x2=='R':          
            if k2==20: #here we check to see if we are at a wall
              k2-=1
            else:
              k2+=1
    K2.append(k2)
    A2.append(a2)
    K1.append(k1)
    A1.append(a1)
    D1.append(choice_x1) #after each loop we then add the changes to our lists of x and y values as well as a list containing the direction of each step
    D1.append(choice_y1)
    D2.append(choice_x2) #after each loop we then add the changes to our lists of x and y values as well as a list containing the direction of each step
    D2.append(choice_y2)

  plt.figure(figsize=(10,10)) #making it bigger
  plt.xlabel('Steps in X direction')
  plt.ylabel('Steps in Y direction') #our x,y labels
  plt.plot(K1,A1,c='blue',alpha=.5,label='walking path starting at (0,0)') #plotting our walking path
  plt.plot(K2,A2,c='yellow',alpha=.5,label='walking path starting at (20,20)') #plotting our walking path
  plt.scatter(0,0,alpha=1,c='purple',s=100,label='start at (0,0)',marker='o') 
  plt.scatter(20,20,alpha=1,c='purple',s=100,label='start at (20,20)',marker='o')
  plt.scatter(Collide_x,Collide_y,c='black',s=100,marker='+',alpha=1,label='collisions ({})'.format(len(Collide_x))) #plot our collisions and count how many times they occur
  plt.scatter(K1[-1],A1[-1],alpha=1,c='red',s=100,label='end of walker 1',marker='x') #plotting points at the start and end of the walk
  plt.scatter(K2[-1],A2[-1],alpha=1,c='red',s=100,label='end of walker 2',marker='x') #plotting points at the start and end of the walk
  plt.legend() #our legend
  plt.grid() #grid lines
  plt.show() #to show
  width = int((max(K1) - min(K1) + 1) * size)#we have to change these because the image doesnt accept floats for size
  height = int((max(A1) - min(A1) + 1) * size)
  origin_x = 0 
  origin_y = 0
  img = Image.new("RGB", (width, height), "white")#then we create an image
  draw = ImageDraw.Draw(img)
  # Draw the points on the image
  for i in range(n+1):
      x1 = (K1[i] + origin_x) * size
      y1 = (A1[i] + origin_y) * size
      x2 = (K2[i] + origin_x) * size
      y2 = (A2[i] + origin_y) * size
      draw.rectangle([x1, y1, x1+size, y1+size], fill=np.random.choice(['red'])) #this draws with a random change of being only red to show walk 1
      draw.rectangle([x2, y2, x2+size, y2+size], fill=np.random.choice(['black'])) #this draws with a random chance of being only black to show walk 2
  img.show()  # this the image

proj_8(1000,20)  # this calls our function with 1000 steps and an image size of 20
# Out:
# <PIL.Image.Image image mode=RGB size=400x380 at 0x7F8AF4228580>

# %% [markdown]
# After watching this function run, I am initially suprprised at only one collision. The paths cross so many times even go multiple steps continuous steps over the same path, but only once meet at the same time. The PIL image looks like the Imessage game called "Filler" where you take turns trying to fill the box with your chosen color. This Image depicts the two walkers trying to fill the given box with their respective color.

# %% [markdown]
# Now that we've got some brute force functions, were going to change focus to using numpy to create scatterplots comparing the end values. This distance form the origin should on average yield the $\sqrt{N}$ result, $N$ being the number of steps taken.
#
# Below we will plot these endpoints:

# %%
import numpy as np
import matplotlib.pyplot as plt

#first lets set up the parameters
num_steps = 1000
num_walks = 1000
step_size = 1

#then initialize the position matrix, having rows the size of 2 and collums the size of the number of walks we take. This pos. matrix should hold the start and endpoints of the random walk
pos = np.zeros((num_walks, 2))

#next preform the random walk
for i in range(num_steps):
    #generate a random vector (of length 1) for each step
    direction = np.random.rand(num_walks, 2) - 0.5
    norm = np.linalg.norm(direction, axis=1)
    direction = direction / np.expand_dims(norm, axis=1)

    #add the step to the current position with an option to change step size later
    pos += step_size * direction

#now we need to find the distances from the origin and then calculate the average
distance = np.linalg.norm(pos, axis=1)
average=np.mean(distance)

print("Here we expect to see an average distance of {} from the origin after {} steps but instead we see {}.".format(np.sqrt(num_steps),num_steps,average))

# Plot the resulting positions
plt.scatter(pos[:, 0], pos[:, 1])
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()
# Out:
# Here we expect to see an average distance of 31.622776601683793 from the origin after 1000 steps but instead we see 27.69762675190669.

# %% [markdown]
# This scatter plot runs 1000 times, but the average distance from the origin seems to be slightly lower than the square root of 1000.

# %% [markdown]
# Next we will create and compare 10 One-Dimensional Random Walks with a wall at 0

# %%
import numpy as np
import matplotlib.pyplot as plt

#set up the parameters
num_steps = 1000
num_walks = 10

#initialize the position matrix
pos = np.zeros((num_walks, num_steps+1))

#perform the random walk
for i in range(num_steps):
    #generate a random direction (-1 or 1) for each step
    direction = np.random.choice([-1, 1], size=num_walks)

    #update the position matrix
    pos[:, i+1] = pos[:, i] + direction

    #apply a wall constraint
    pos[pos[:, i+1] < 0, i+1] = 0

#plot the resulting positions
plt.xlabel('Steps')
plt.ylabel('Distance from 0')
plt.grid()
plt.plot(pos.T)
plt.show()

# %% [markdown]
# Now we will compare 100 different random walks with gravity and a floor.

# %%
import numpy as np
import matplotlib.pyplot as plt

#set up the parameters
num_steps = 1000
num_walks = 100
step_size = 1
gravity = 0.1

#initialize the position matrix
pos = np.zeros((num_walks, 2))

#perform the random walk
for i in range(num_steps):
    #generate a random vector (of length 1) for each step
    direction = np.random.rand(num_walks, 2) - 0.5
    norm = np.linalg.norm(direction, axis=1)
    direction = direction / np.expand_dims(norm, axis=1)

    #apply the gravity and step size
    direction[:, 1] -= gravity
    direction *= step_size

    #update the position matrix
    pos += direction

    #apply the floor constraint
    pos[pos[:, 1] < 0, 1] = 0
    pos[:, 1] = np.maximum(pos[:, 1], 0)

#plot the resulting positions
plt.scatter(pos[:, 0], pos[:, 1])
plt.xlabel('Floor')
plt.ylabel('Height')
plt.show()
